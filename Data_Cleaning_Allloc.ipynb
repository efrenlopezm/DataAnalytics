# %%
import pandas as pd

# %% [markdown]
# # Have taken Avg Temp, Precipitation, Avg Snow & Avg Wind of 5 cities
# ## Corpus Christi, New York, Seattle, Colorado & Oklahoma Airports.
# ### Loading & Cleaning data for Corpus Christi Airport Station
# df=pd.read_csv('CcAIrport.csv')

# %%
df.info
df.head()
# Out:
#        STATION                                         NAME     DATE  AWND  \
# 0  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  1970-01   NaN
# 1  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  1970-02   NaN
# 2  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  1970-03   NaN
# 3  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  1970-04   NaN
# 4  USW00012924  CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US  1970-05   NaN
#
#    PRCP  SNOW  TAVG
# 0  1.80   0.0  51.2
# 1  1.02   0.0  59.0
# 2  1.56   0.0  60.9
# 3  0.15   0.0  73.3
# 4  3.93   0.0  75.3

# %%
df.values
# Out:
# array([['USW00012924', 'CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US',
#         '1970-01', ..., 1.8, 0.0, 51.2],
#        ['USW00012924', 'CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US',
#         '1970-02', ..., 1.02, 0.0, 59.0],
#        ['USW00012924', 'CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US',
#         '1970-03', ..., 1.56, 0.0, 60.9],
#        ...,
#        ['USW00012924', 'CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US',
#         '2022-06', ..., 0.27, 0.0, 83.7],
#        ['USW00012924', 'CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US',
#         '2022-07', ..., 0.54, 0.0, 85.4],
#        ['USW00012924', 'CORPUS CHRISTI INTERNATIONAL AIRPORT, TX US',
#         '2022-08', ..., 11.21, 0.0, 85.7]], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  632 non-null    object
#  1   NAME     632 non-null    object
#  2   DATE     632 non-null    object
#  3   AWND     464 non-null    float64
#  4   PRCP     632 non-null    float64
#  5   SNOW     632 non-null    float64
#  6   TAVG     632 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 34.7+ KB

# %%
df.isnull()
# Out:
#      STATION   NAME   DATE   AWND   PRCP   SNOW   TAVG
# 0      False  False  False   True  False  False  False
# 1      False  False  False   True  False  False  False
# 2      False  False  False   True  False  False  False
# 3      False  False  False   True  False  False  False
# 4      False  False  False   True  False  False  False
# ..       ...    ...    ...    ...    ...    ...    ...
# 627    False  False  False  False  False  False  False
# 628    False  False  False  False  False  False  False
# 629    False  False  False  False  False  False  False
# 630    False  False  False  False  False  False  False
# 631    False  False  False  False  False  False  False
#
# [632 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# STATION      0
# NAME         0
# DATE         0
# AWND       168
# PRCP         0
# SNOW         0
# TAVG         0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 168

# %% [markdown]
# ### Finding Null Values from the Excel & taking the mean of Awind Column.
#
# dfcccl = df.fillna(value=df['AWND'].mean())
# dfcccl

# %%
dfcccl.isnull().sum()
# Out:
# STATION    0
# NAME       0
# DATE       0
# AWND       0
# PRCP       0
# SNOW       0
# TAVG       0
# dtype: int64

# %% [markdown]
# ### Loading & Cleaning data for New York Airport Station

# %%
df1=pd.read_csv('NYAIrport.csv')

# %%
df1.info
# Out:
# <bound method DataFrame.info of          STATION                              NAME     DATE  AWND  PRCP  SNOW  \
# 0    USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-01   NaN  0.56   5.6
# 1    USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-02   NaN  3.33   5.3
# 2    USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-03   NaN  4.04   2.4
# 3    USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-04   NaN  3.15   0.0
# 4    USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-05   NaN  2.01   0.0
# ..           ...                               ...      ...   ...   ...   ...
# 627  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2022-04  13.9  3.09   0.0
# 628  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2022-05  10.5  4.34   0.0
# 629  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2022-06  10.7  3.25   0.0
# 630  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2022-07  10.5  1.10   0.0
# 631  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2022-08  10.1  0.85   0.0
#
# ...

# %%
df1.head()
# Out:
#        STATION                              NAME     DATE  AWND  PRCP  SNOW  \
# 0  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-01   NaN  0.56   5.6
# 1  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-02   NaN  3.33   5.3
# 2  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-03   NaN  4.04   2.4
# 3  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-04   NaN  3.15   0.0
# 4  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-05   NaN  2.01   0.0
#
#    TAVG
# 0  26.7
# 1  33.3
# 2  37.5
# 3  49.9
# 4  61.7

# %%
df1.values
# Out:
# array([['USW00094789', 'JFK INTERNATIONAL AIRPORT, NY US', '1970-01',
#         ..., 0.56, 5.6, 26.7],
#        ['USW00094789', 'JFK INTERNATIONAL AIRPORT, NY US', '1970-02',
#         ..., 3.33, 5.3, 33.3],
#        ['USW00094789', 'JFK INTERNATIONAL AIRPORT, NY US', '1970-03',
#         ..., 4.04, 2.4, 37.5],
#        ...,
#        ['USW00094789', 'JFK INTERNATIONAL AIRPORT, NY US', '2022-06',
#         ..., 3.25, 0.0, 70.3],
#        ['USW00094789', 'JFK INTERNATIONAL AIRPORT, NY US', '2022-07',
#         ..., 1.1, 0.0, 79.3],
#        ['USW00094789', 'JFK INTERNATIONAL AIRPORT, NY US', '2022-08',
#         ..., 0.85, 0.0, 78.7]], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  632 non-null    object
#  1   NAME     632 non-null    object
#  2   DATE     632 non-null    object
#  3   AWND     464 non-null    float64
#  4   PRCP     632 non-null    float64
#  5   SNOW     632 non-null    float64
#  6   TAVG     632 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 34.7+ KB

# %%
df1.isnull()
# Out:
#      STATION   NAME   DATE   AWND   PRCP   SNOW   TAVG
# 0      False  False  False   True  False  False  False
# 1      False  False  False   True  False  False  False
# 2      False  False  False   True  False  False  False
# 3      False  False  False   True  False  False  False
# 4      False  False  False   True  False  False  False
# ..       ...    ...    ...    ...    ...    ...    ...
# 627    False  False  False  False  False  False  False
# 628    False  False  False  False  False  False  False
# 629    False  False  False  False  False  False  False
# 630    False  False  False  False  False  False  False
# 631    False  False  False  False  False  False  False
#
# [632 rows x 7 columns]

# %%
df1.isnull().sum()
# Out:
# STATION      0
# NAME         0
# DATE         0
# AWND       168
# PRCP         0
# SNOW         0
# TAVG         0
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 168

# %%
## Finding Null Values from the Excel & taking the mean of Awind Column.

dfNYCleaned = df1.fillna(value=df['AWND'].mean())
dfNYCleaned
# Out:
#          STATION                              NAME     DATE       AWND  PRCP  \
# 0    USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-01  11.648707  0.56
# 1    USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-02  11.648707  3.33
# 2    USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-03  11.648707  4.04
# 3    USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-04  11.648707  3.15
# 4    USW00094789  JFK INTERNATIONAL AIRPORT, NY US  1970-05  11.648707  2.01
# ..           ...                               ...      ...        ...   ...
# 627  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2022-04  13.900000  3.09
# 628  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2022-05  10.500000  4.34
# 629  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2022-06  10.700000  3.25
# 630  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2022-07  10.500000  1.10
# 631  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  2022-08  10.100000  0.85
#
#      SNOW  TAVG
# 0     5.6  26.7
# ...

# %%
dfNYCleaned.isnull().sum()
# Out:
# STATION    0
# NAME       0
# DATE       0
# AWND       0
# PRCP       0
# SNOW       0
# TAVG       0
# dtype: int64

# %%
dfNYCleaned.isnull().sum().sum()
# Out:
# 0

# %%
### Loading & Cleaning data for Colorado Municipal Airport Station
df2=pd.read_csv('ColordoMuniAirport.csv')

# %%
df2.info
# Out:
# <bound method DataFrame.info of          STATION                                       NAME  LATITUDE  \
# 0    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 1    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 2    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 3    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 4    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# ..           ...                                        ...       ...
# 413  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 414  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 415  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 416  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 417  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
#
#      LONGITUDE  ELEVATION     DATE  AWND  PRCP  SNOW  TAVG
# ...

# %%
df2.head()
# Out:
#        STATION                                       NAME  LATITUDE  \
# 0  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 1  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 2  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 3  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 4  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
#
#    LONGITUDE  ELEVATION     DATE  AWND  PRCP  SNOW  TAVG
# 0 -104.68873     1884.2  1987-11   9.4  0.44   4.8  39.2
# 1 -104.68873     1884.2  1987-12   9.8  0.64   9.5  29.0
# 2 -104.68873     1884.2  1988-01  10.1  0.43   4.9  24.3
# 3 -104.68873     1884.2  1988-02   9.4  0.68  11.5  31.7
# 4 -104.68873     1884.2  1988-03  11.0  0.90  12.6  36.2

# %%
df2.values
# Out:
# array([['USW00093037', 'COLORADO SPRINGS MUNICIPAL AIRPORT, CO US',
#         38.80949, ..., 0.44, 4.8, 39.2],
#        ['USW00093037', 'COLORADO SPRINGS MUNICIPAL AIRPORT, CO US',
#         38.80949, ..., 0.64, 9.5, 29.0],
#        ['USW00093037', 'COLORADO SPRINGS MUNICIPAL AIRPORT, CO US',
#         38.80949, ..., 0.43, 4.9, 24.3],
#        ...,
#        ['USW00093037', 'COLORADO SPRINGS MUNICIPAL AIRPORT, CO US',
#         38.80949, ..., 1.37, 0.0, 68.5],
#        ['USW00093037', 'COLORADO SPRINGS MUNICIPAL AIRPORT, CO US',
#         38.80949, ..., 5.35, 0.0, 74.7],
#        ['USW00093037', 'COLORADO SPRINGS MUNICIPAL AIRPORT, CO US',
#         38.80949, ..., 1.82, 0.0, 71.7]], dtype=object)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATION    418 non-null    object
#  1   NAME       418 non-null    object
#  2   LATITUDE   418 non-null    float64
#  3   LONGITUDE  418 non-null    float64
#  4   ELEVATION  418 non-null    float64
#  5   DATE       418 non-null    object
#  6   AWND       417 non-null    float64
#  7   PRCP       418 non-null    float64
#  8   SNOW       418 non-null    float64
#  9   TAVG       418 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 32.8+ KB

# %%
df2.isnull()
# Out:
#      STATION   NAME  LATITUDE  LONGITUDE  ELEVATION   DATE   AWND   PRCP  \
# 0      False  False     False      False      False  False  False  False
# 1      False  False     False      False      False  False  False  False
# 2      False  False     False      False      False  False  False  False
# 3      False  False     False      False      False  False  False  False
# 4      False  False     False      False      False  False  False  False
# ..       ...    ...       ...        ...        ...    ...    ...    ...
# 413    False  False     False      False      False  False  False  False
# 414    False  False     False      False      False  False  False  False
# 415    False  False     False      False      False  False  False  False
# 416    False  False     False      False      False  False  False  False
# 417    False  False     False      False      False  False  False  False
#
#       SNOW   TAVG
# 0    False  False
# 1    False  False
# 2    False  False
# ...

# %%
df2.isnull().sum()
# Out:
# STATION      0
# NAME         0
# LATITUDE     0
# LONGITUDE    0
# ELEVATION    0
# DATE         0
# AWND         1
# PRCP         0
# SNOW         0
# TAVG         0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 1

# %% [markdown]
# ### Finding Null Values from the Excel & Interpolating the missing values in Awind Column.

# %%
dfColoCleaned = df2

# %%
dfColoCleaned
# Out:
#          STATION                                       NAME  LATITUDE  \
# 0    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 1    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 2    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 3    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 4    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# ..           ...                                        ...       ...
# 413  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 414  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 415  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 416  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 417  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
#
#      LONGITUDE  ELEVATION     DATE  AWND  PRCP  SNOW  TAVG
# 0   -104.68873     1884.2  1987-11   9.4  0.44   4.8  39.2
# ...

# %%
dfColoCleaned.isnull().sum().sum()
# Out:
# 1

# %%
dfColoCleaned['AWND'] = dfColoCleaned['AWND'].interpolate(method='linear')
dfColoCleaned
# Out:
#          STATION                                       NAME  LATITUDE  \
# 0    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 1    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 2    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 3    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 4    USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# ..           ...                                        ...       ...
# 413  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 414  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 415  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 416  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
# 417  USW00093037  COLORADO SPRINGS MUNICIPAL AIRPORT, CO US  38.80949
#
#      LONGITUDE  ELEVATION     DATE  AWND  PRCP  SNOW  TAVG
# 0   -104.68873     1884.2  1987-11   9.4  0.44   4.8  39.2
# ...

# %%
dfColoCleaned.isnull().sum()
# Out:
# STATION      0
# NAME         0
# LATITUDE     0
# LONGITUDE    0
# ELEVATION    0
# DATE         0
# AWND         0
# PRCP         0
# SNOW         0
# TAVG         0
# dtype: int64

# %%
dfColoCleaned.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Loading & Cleaning data for Seattle Airport Station

# %%
df3=pd.read_csv('SEAirport.csv')

# %%
df3.info
# Out:
# <bound method DataFrame.info of          STATION                           NAME     DATE  AWND  PRCP  SNOW  \
# 0    USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-01   NaN  8.22   0.0
# 1    USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-02   NaN  2.26   0.0
# 2    USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-03   NaN  3.16   0.0
# 3    USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-04   NaN  3.32   0.0
# 4    USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-05   NaN  1.17   0.0
# ..           ...                            ...      ...   ...   ...   ...
# 627  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2022-04   8.9  2.72   0.0
# 628  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2022-05   7.8  3.82   0.0
# 629  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2022-06   7.6  2.68   0.0
# 630  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2022-07   6.7  0.19   0.0
# 631  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2022-08   7.2  0.05   0.0
#
#      TAVG
# 0    41.2
# 1    47.0
# ...

# %%
df3.head()
# Out:
#        STATION                           NAME     DATE  AWND  PRCP  SNOW  TAVG
# 0  USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-01   NaN  8.22   0.0  41.2
# 1  USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-02   NaN  2.26   0.0  47.0
# 2  USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-03   NaN  3.16   0.0  46.0
# 3  USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-04   NaN  3.32   0.0  46.1
# 4  USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-05   NaN  1.17   0.0  54.7

# %%
df3.values
# Out:
# array([['USW00024233', 'SEATTLE TACOMA AIRPORT, WA US', '1970-01', ...,
#         8.22, 0.0, 41.2],
#        ['USW00024233', 'SEATTLE TACOMA AIRPORT, WA US', '1970-02', ...,
#         2.26, 0.0, 47.0],
#        ['USW00024233', 'SEATTLE TACOMA AIRPORT, WA US', '1970-03', ...,
#         3.16, 0.0, 46.0],
#        ...,
#        ['USW00024233', 'SEATTLE TACOMA AIRPORT, WA US', '2022-06', ...,
#         2.68, 0.0, 61.1],
#        ['USW00024233', 'SEATTLE TACOMA AIRPORT, WA US', '2022-07', ...,
#         0.19, 0.0, 69.0],
#        ['USW00024233', 'SEATTLE TACOMA AIRPORT, WA US', '2022-08', ...,
#         0.05, 0.0, 70.0]], dtype=object)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  632 non-null    object
#  1   NAME     632 non-null    object
#  2   DATE     632 non-null    object
#  3   AWND     464 non-null    float64
#  4   PRCP     632 non-null    float64
#  5   SNOW     632 non-null    float64
#  6   TAVG     632 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 34.7+ KB

# %%
df3.isnull()
# Out:
#      STATION   NAME   DATE   AWND   PRCP   SNOW   TAVG
# 0      False  False  False   True  False  False  False
# 1      False  False  False   True  False  False  False
# 2      False  False  False   True  False  False  False
# 3      False  False  False   True  False  False  False
# 4      False  False  False   True  False  False  False
# ..       ...    ...    ...    ...    ...    ...    ...
# 627    False  False  False  False  False  False  False
# 628    False  False  False  False  False  False  False
# 629    False  False  False  False  False  False  False
# 630    False  False  False  False  False  False  False
# 631    False  False  False  False  False  False  False
#
# [632 rows x 7 columns]

# %%
df3.isnull().sum()
# Out:
# STATION      0
# NAME         0
# DATE         0
# AWND       168
# PRCP         0
# SNOW         0
# TAVG         0
# dtype: int64

# %%
df3.isnull().sum().sum()
# Out:
# 168

# %% [markdown]
# ### Finding Null Values from the Excel & taking the mean of Awind Column.

# %%
dfSeattleCleaned = df3.fillna(value=df['AWND'].mean())
dfSeattleCleaned
# Out:
#          STATION                           NAME     DATE       AWND  PRCP  \
# 0    USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-01  11.648707  8.22
# 1    USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-02  11.648707  2.26
# 2    USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-03  11.648707  3.16
# 3    USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-04  11.648707  3.32
# 4    USW00024233  SEATTLE TACOMA AIRPORT, WA US  1970-05  11.648707  1.17
# ..           ...                            ...      ...        ...   ...
# 627  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2022-04   8.900000  2.72
# 628  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2022-05   7.800000  3.82
# 629  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2022-06   7.600000  2.68
# 630  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2022-07   6.700000  0.19
# 631  USW00024233  SEATTLE TACOMA AIRPORT, WA US  2022-08   7.200000  0.05
#
#      SNOW  TAVG
# 0     0.0  41.2
# 1     0.0  47.0
# 2     0.0  46.0
# ...

# %%
dfSeattleCleaned.isnull().sum()
# Out:
# STATION    0
# NAME       0
# DATE       0
# AWND       0
# PRCP       0
# SNOW       0
# TAVG       0
# dtype: int64

# %%
dfSeattleCleaned.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Loading & Cleaning data for Oklahoma Airport Station

# %%
df4=pd.read_csv('OklaAirport.csv')

# %%
df4.info
# Out:
# <bound method DataFrame.info of          STATION                                            NAME     DATE  \
# 0    USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-07
# 1    USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-08
# 2    USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-09
# 3    USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-10
# 4    USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-11
# ..           ...                                             ...      ...
# 620  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  2022-03
# 621  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  2022-04
# 622  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  2022-05
# 623  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  2022-06
# 624  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  2022-07
#
#      AWND  PRCP  SNOW  TAVG
# ...

# %%
df4.head()
# Out:
#        STATION                                            NAME     DATE  AWND  \
# 0  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-07   NaN
# 1  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-08   NaN
# 2  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-09   NaN
# 3  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-10   NaN
# 4  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-11   NaN
#
#    PRCP  SNOW  TAVG
# 0  1.30   0.0  82.1
# 1  0.80   0.0  83.6
# 2  9.65   0.0  75.1
# 3  3.30   0.0  57.9
# 4  1.03   0.0  46.0

# %%
df4.values
# Out:
# array([['USW00013967', 'OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US',
#         '1970-07', ..., 1.3, 0.0, 82.1],
#        ['USW00013967', 'OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US',
#         '1970-08', ..., 0.8, 0.0, 83.6],
#        ['USW00013967', 'OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US',
#         '1970-09', ..., 9.65, 0.0, 75.1],
#        ...,
#        ['USW00013967', 'OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US',
#         '2022-05', ..., 7.35, 0.0, 70.5],
#        ['USW00013967', 'OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US',
#         '2022-06', ..., 3.31, 0.0, 78.7],
#        ['USW00013967', 'OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US',
#         '2022-07', ..., 0.42, 0.0, 86.4]], dtype=object)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  625 non-null    object
#  1   NAME     625 non-null    object
#  2   DATE     625 non-null    object
#  3   AWND     463 non-null    float64
#  4   PRCP     625 non-null    float64
#  5   SNOW     625 non-null    float64
#  6   TAVG     625 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 34.3+ KB

# %%
df4.isnull()
# Out:
#      STATION   NAME   DATE   AWND   PRCP   SNOW   TAVG
# 0      False  False  False   True  False  False  False
# 1      False  False  False   True  False  False  False
# 2      False  False  False   True  False  False  False
# 3      False  False  False   True  False  False  False
# 4      False  False  False   True  False  False  False
# ..       ...    ...    ...    ...    ...    ...    ...
# 620    False  False  False  False  False  False  False
# 621    False  False  False  False  False  False  False
# 622    False  False  False  False  False  False  False
# 623    False  False  False  False  False  False  False
# 624    False  False  False  False  False  False  False
#
# [625 rows x 7 columns]

# %%
df4.isnull().sum()
# Out:
# STATION      0
# NAME         0
# DATE         0
# AWND       162
# PRCP         0
# SNOW         0
# TAVG         0
# dtype: int64

# %%
df4.isnull().sum().sum()
# Out:
# 162

# %% [markdown]
# ### Finding Null Values from the Excel & taking the mean of Awind Column.

# %%
dfOklaCleaned = df4.fillna(value=df['AWND'].mean())
dfOklaCleaned
# Out:
#          STATION                                            NAME     DATE  \
# 0    USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-07
# 1    USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-08
# 2    USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-09
# 3    USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-10
# 4    USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  1970-11
# ..           ...                                             ...      ...
# 620  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  2022-03
# 621  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  2022-04
# 622  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  2022-05
# 623  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  2022-06
# 624  USW00013967  OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US  2022-07
#
#           AWND  PRCP  SNOW  TAVG
# 0    11.648707  1.30   0.0  82.1
# ...

# %%
dfOklaCleaned.isnull().sum()
# Out:
# STATION    0
# NAME       0
# DATE       0
# AWND       0
# PRCP       0
# SNOW       0
# TAVG       0
# dtype: int64

# %% [markdown]
# ### Loading and Cleaning Gridded Dataset

# %%
df5 = pd.read_csv('USAGrid.csv')

# %%
df5
# Out:
#             STATION                                NAME  LATITUDE  LONGITUDE  \
# 0       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 1       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 2       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 3       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 4       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# ...             ...                                 ...       ...        ...
# 381083  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381084  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381085  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381086  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381087  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
#
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381088 entries, 0 to 381087
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   STATION    381088 non-null  object
#  1   NAME       381088 non-null  object
#  2   LATITUDE   381088 non-null  float64
#  3   LONGITUDE  381088 non-null  float64
#  4   ELEVATION  381088 non-null  float64
#  5   DATE       381088 non-null  object
#  6   AWND       381052 non-null  float64
#  7   PRCP       374894 non-null  float64
#  8   SNOW       248564 non-null  float64
#  9   TAVG       374452 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 29.1+ MB

# %%
df5.head
# Out:
# <bound method NDFrame.head of             STATION                                NAME  LATITUDE  LONGITUDE  \
# 0       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 1       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 2       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 3       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 4       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# ...             ...                                 ...       ...        ...
# 381083  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381084  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381085  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381086  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381087  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
#
# ...

# %%
df5.values
# Out:
# array([['USW00053819', 'PEACHTREE CITY FALCON FIELD, GA US', 33.35428,
#         ..., 5.06, 0.0, 75.5],
#        ['USW00053819', 'PEACHTREE CITY FALCON FIELD, GA US', 33.35428,
#         ..., 5.58, 0.0, 69.9],
#        ['USW00053819', 'PEACHTREE CITY FALCON FIELD, GA US', 33.35428,
#         ..., 5.3, 0.0, 60.2],
#        ...,
#        ['USW00012819', 'LEESBURG MUNICIPAL AIRPORT, FL US', 28.82143,
#         ..., 3.61, 0.0, 65.9],
#        ['USW00012819', 'LEESBURG MUNICIPAL AIRPORT, FL US', 28.82143,
#         ..., 1.86, 0.0, 69.7],
#        ['USW00012819', 'LEESBURG MUNICIPAL AIRPORT, FL US', 28.82143,
#         ..., 1.11, 0.0, 58.4]], dtype=object)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381088 entries, 0 to 381087
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   STATION    381088 non-null  object
#  1   NAME       381088 non-null  object
#  2   LATITUDE   381088 non-null  float64
#  3   LONGITUDE  381088 non-null  float64
#  4   ELEVATION  381088 non-null  float64
#  5   DATE       381088 non-null  object
#  6   AWND       246091 non-null  float64
#  7   PRCP       374894 non-null  float64
#  8   SNOW       248564 non-null  float64
#  9   TAVG       374452 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 29.1+ MB

# %%
df5.isnull()
# Out:
#         STATION   NAME  LATITUDE  LONGITUDE  ELEVATION   DATE   AWND   PRCP  \
# 0         False  False     False      False      False  False   True  False
# 1         False  False     False      False      False  False   True  False
# 2         False  False     False      False      False  False   True  False
# 3         False  False     False      False      False  False   True  False
# 4         False  False     False      False      False  False   True  False
# ...         ...    ...       ...        ...        ...    ...    ...    ...
# 381083    False  False     False      False      False  False  False  False
# 381084    False  False     False      False      False  False  False  False
# 381085    False  False     False      False      False  False  False  False
# 381086    False  False     False      False      False  False  False  False
# 381087    False  False     False      False      False  False  False  False
#
#          SNOW   TAVG
# 0       False  False
# ...

# %%
df5.isnull().sum()
# Out:
# STATION           0
# NAME              0
# LATITUDE          0
# LONGITUDE         0
# ELEVATION         0
# DATE              0
# AWND         134997
# PRCP           6194
# SNOW         132524
# TAVG           6636
# dtype: int64

# %%
df5.isnull().sum().sum()
# Out:
# 280351

# %% [markdown]
# ### Finding Null Values from the Excel & Interpolating the missing values in Awind Column.

# %%
df_Gridded_clean = df5
df_Gridded_clean
# Out:
#             STATION                                NAME  LATITUDE  LONGITUDE  \
# 0       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 1       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 2       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 3       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# 4       USW00053819  PEACHTREE CITY FALCON FIELD, GA US  33.35428  -84.56896
# ...             ...                                 ...       ...        ...
# 381083  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381084  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381085  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381086  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
# 381087  USW00012819   LEESBURG MUNICIPAL AIRPORT, FL US  28.82143  -81.80963
#
# ...

# %%
df_clean= df5.fillna({df5['AWND'].interpolate()})
df_clean.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df_clean= df5.fillna({df5['AWND'].interpolate()})
#       2 df_clean.head()
#
# TypeError: unhashable type: 'Series'

# %%
df_Gridded_clean.isnull()
# Out:
#       STATION   NAME  LATITUDE  LONGITUDE  ELEVATION   DATE   AWND   PRCP  \
# 0       False  False     False      False      False  False  False  False
# 1       False  False     False      False      False  False  False  False
# 2       False  False     False      False      False  False  False  False
# 3       False  False     False      False      False  False  False  False
# 4       False  False     False      False      False  False  False  False
# ...       ...    ...       ...        ...        ...    ...    ...    ...
# 1245    False  False     False      False      False  False   True  False
# 1246    False  False     False      False      False  False   True  False
# 1247    False  False     False      False      False  False   True  False
# 1248    False  False     False      False      False  False   True  False
# 1249    False  False     False      False      False  False   True  False
#
#        SNOW   TAVG
# 0     False  False
# 1     False  False
# ...

# %%
df_Gridded_clean.isnull().sum()
# Out:
# STATION           0
# NAME              0
# LATITUDE          0
# LONGITUDE         0
# ELEVATION         0
# DATE              0
# AWND             36
# PRCP           6194
# SNOW         132524
# TAVG           6636
# dtype: int64

# %% [markdown]
# ## Unable to Interpolate data so taking mean of all the AWIND(Average Wind Speeds)

# %% [markdown]
# ### Finding Null Values from the Excel & taking the mean of Awind Column.

# %%
dfGridded_Clean_2 = df5.fillna(value=df['AWND'].mean())
dfGridded_Clean_2
# Out:
#           STATION                              NAME  LATITUDE  LONGITUDE  \
# 0     USW00014732          LAGUARDIA AIRPORT, NY US  40.77945  -73.88027
# 1     USW00014732          LAGUARDIA AIRPORT, NY US  40.77945  -73.88027
# 2     USW00014732          LAGUARDIA AIRPORT, NY US  40.77945  -73.88027
# 3     USW00014732          LAGUARDIA AIRPORT, NY US  40.77945  -73.88027
# 4     USW00014732          LAGUARDIA AIRPORT, NY US  40.77945  -73.88027
# ...           ...                               ...       ...        ...
# 1245  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915  -73.76390
# 1246  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915  -73.76390
# 1247  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915  -73.76390
# 1248  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915  -73.76390
# 1249  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  40.63915  -73.76390
#
#       ELEVATION     DATE       AWND  PRCP  SNOW  TAVG
# ...

# %%
dfGridded_Clean_2.isnull()
# Out:
#       STATION   NAME  LATITUDE  LONGITUDE  ELEVATION   DATE   AWND   PRCP  \
# 0       False  False     False      False      False  False  False  False
# 1       False  False     False      False      False  False  False  False
# 2       False  False     False      False      False  False  False  False
# 3       False  False     False      False      False  False  False  False
# 4       False  False     False      False      False  False  False  False
# ...       ...    ...       ...        ...        ...    ...    ...    ...
# 1245    False  False     False      False      False  False  False  False
# 1246    False  False     False      False      False  False  False  False
# 1247    False  False     False      False      False  False  False  False
# 1248    False  False     False      False      False  False  False  False
# 1249    False  False     False      False      False  False  False  False
#
#        SNOW   TAVG
# 0     False  False
# 1     False  False
# ...

# %%
dfGridded_Clean_2.isnull().sum()
# Out:
# STATION      0
# NAME         0
# LATITUDE     0
# LONGITUDE    0
# ELEVATION    0
# DATE         0
# AWND         0
# PRCP         0
# SNOW         0
# TAVG         0
# dtype: int64

# %%
dfGridded_Clean_2.isnull().sum().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# %%
dfOklaCleaned.plot(x='DATE',y='PRCP')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
dfOklaCleaned.plot(x='DATE',y='AWND')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
dfOklaCleaned.plot(x='DATE',y='SNOW')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
dfOklaCleaned.plot(x='DATE',y='TAVG')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
dfcccl.plot(x='DATE',y='AWND')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
dfcccl.plot(x='DATE',y='TAVG')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df_clean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 df_clean
#
# NameError: name 'df_clean' is not defined

# %%
dfOklaCleaned.isnull().sum().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 dfOklaCleaned.isnull().sum().sum()
#
# NameError: name 'dfOklaCleaned' is not defined
